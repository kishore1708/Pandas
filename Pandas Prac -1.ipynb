# %%
import pandas as pd

# %%
a=[1,2,3,4,5,6,7,8]

# %%
df=pd.read_csv("addresses.csv")
# df=pd.read_csv("addresses.csv",header=None)
# df=pd.read_csv("addresses.csv",names=['add1','add2','add3','add4','add5','add6','add7','add8'])
# df=pd.read_csv("addresses.csv",names=['add1','add2','add3','add4','add5','add6','add7','add8','add9'])

# %%
df #First row -->colun name ; Index numbering -->Row name
# Out:
#     id  location_id                   address_1  address_2  \
# 0    1            1       2600 Middlefield Road        NaN
# 1    2            2            24 Second Avenue        NaN
# 2    3            3            24 Second Avenue        NaN
# 3    4            4            24 Second Avenue        NaN
# 4    5            5            24 Second Avenue        NaN
# 5    6            6           800 Middle Avenue        NaN
# 6    7            7              500 Arbor Road        NaN
# 7    8            8           800 Middle Avenue        NaN
# 8    9            9       2510 Middlefield Road        NaN
# 9   10           10       1044 Middlefield Road        NaN
# 10  11           11         2140 Euclid Avenue.        NaN
# 11  12           12       1044 Middlefield Road  2nd Floor
# 12  13           13         399 Marine Parkway.        NaN
# 13  14           14          660 Veterans Blvd.        NaN
# 14  15           15        1500 Valencia Street        NaN
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
type(df['id'])
# Out:
# pandas.core.series.Series

# %%
df1=pd.read_csv("addresses.csv",skiprows=[1,2])

# %%
df1
# Out:
#     id  location_id                   address_1  address_2  \
# 0    3            3            24 Second Avenue        NaN
# 1    4            4            24 Second Avenue        NaN
# 2    5            5            24 Second Avenue        NaN
# 3    6            6           800 Middle Avenue        NaN
# 4    7            7              500 Arbor Road        NaN
# 5    8            8           800 Middle Avenue        NaN
# 6    9            9       2510 Middlefield Road        NaN
# 7   10           10       1044 Middlefield Road        NaN
# 8   11           11         2140 Euclid Avenue.        NaN
# 9   12           12       1044 Middlefield Road  2nd Floor
# 10  13           13         399 Marine Parkway.        NaN
# 11  14           14          660 Veterans Blvd.        NaN
# 12  15           15        1500 Valencia Street        NaN
# 13  16           16         1161 South Bernardo        NaN
# 14  17           17     409 South Spruce Avenue        NaN
# ...

# %%
df1.dtypes
# Out:
# id                 int64
# location_id        int64
# address_1         object
# address_2         object
# city              object
# state_province    object
# postal_code       object
# country           object
# dtype: object

# %%
list(df1.columns)
# Out:
# ['id',
#  'location_id',
#  'address_1',
#  'address_2',
#  'city',
#  'state_province',
#  'postal_code',
#  'country']

# %%
df1[['id','city']]
# Out:
#     id                 city
# 0    3            San Mateo
# 1    4            San Mateo
# 2    5            San Mateo
# 3    6           Menlo Park
# 4    7           Menlo Park
# 5    8           Menlo Park
# 6    9         Redwood City
# 7   10         Redwood City
# 8   11         Redwood City
# 9   12         Redwood City
# 10  13         Redwood City
# 11  14         Redwood City
# 12  15        San Francisco
# 13  16            Sunnyvale
# 14  17  South San Francisco
# 15  18         Redwood City
# 16  19            San Mateo
# 17  20              Belmont
# 18  21        San Francisco

# %%
ls
# Out:
# 02-Series.ipynb
# 03-DataFrames.ipynb
# 04-Missing_Data.ipynb
# 05-Groupby.ipynb
# 06-Merging,_Joining,_and_Concatenating.ipynb
# Pandas Prac -1.ipynb
# Pandas practise.ipynb
# Pandas-DataFrame-Notes.pdf
# Seasonality_index.xlsx
# addresses.csv
# pandas-cheat-sheet-fixed.pdf
# pokemon_data.csv
# pokemon_data.txt

# %%
pd.read_excel("Seasonality_index.xlsx",sheet_name='Sheet1')
# Out:
#          Date  Marketing Spends  SUM values       S.I
# 0  2017-01-01            176732      383304  0.970671
# 1  2017-02-01            180486      361769  0.916137
# 2  2017-03-01            180455      356680  0.903249
# 3  2017-04-01            185070      371350  0.940399
# 4  2017-05-01            195915      391537  0.991521
# 5  2017-06-01            194849      390320  0.988439
# 6  2017-07-01            175999      362796  0.918737
# 7  2017-08-01            167606      351741  0.890742
# 8  2017-09-01            204624      405134  1.025953
# 9  2017-10-01            208619      419625  1.062650
# 10 2017-11-01            211209      449365  1.137963
# 11 2017-12-01            235248      495004  1.253538
# 12 2018-01-01            206572      383304       NaN
# 13 2018-02-01            181283      361769       NaN
# 14 2018-03-01            176225      356680       NaN
# 15 2018-04-01            186280      371350       NaN
# ...

# %%
a=pd.ExcelFile("Seasonality_index.xlsx")

# %%
a.sheet_names
# Out:
# ['Sheet1', 'Sheet2']

# %%
html=pd.read_html("https://www.basketball-reference.com/leagues/NBA_2022_games.html")

# %%
#Scrap only tabular format of data,other elements it won't fetch
# Returns list with tables as element

# %%
html
# Out:
# [                 Date Start (ET)         Visitor/Neutral  PTS  \
#  0   Tue, Oct 19, 2021      7:30p           Brooklyn Nets  104
#  1   Tue, Oct 19, 2021     10:00p   Golden State Warriors  121
#  2   Wed, Oct 20, 2021      7:00p          Indiana Pacers  122
#  3   Wed, Oct 20, 2021      7:00p           Chicago Bulls   94
#  4   Wed, Oct 20, 2021      7:30p          Boston Celtics  134
#  ..                ...        ...                     ...  ...
#  88  Sun, Oct 31, 2021      3:30p        Sacramento Kings   99
#  89  Sun, Oct 31, 2021      7:00p  Portland Trail Blazers  113
#  90  Sun, Oct 31, 2021      7:00p               Utah Jazz  107
#  91  Sun, Oct 31, 2021      7:30p         Detroit Pistons   91
#  92  Sun, Oct 31, 2021     10:30p         Houston Rockets   85
#
#            Home/Neutral  PTS.1 Unnamed: 6 Unnamed: 7  Attend.  Notes
#  0      Milwaukee Bucks    127  Box Score        NaN  17341.0    NaN
#  1   Los Angeles Lakers    114  Box Score        NaN  18997.0    NaN
# ...

# %%
type(html)
# Out:
# list

# %%
len(html)
# Out:
# 1

# %%
html[0]
# Out:
#                  Date Start (ET)         Visitor/Neutral  PTS  \
# 0   Tue, Oct 19, 2021      7:30p           Brooklyn Nets  104
# 1   Tue, Oct 19, 2021     10:00p   Golden State Warriors  121
# 2   Wed, Oct 20, 2021      7:00p          Indiana Pacers  122
# 3   Wed, Oct 20, 2021      7:00p           Chicago Bulls   94
# 4   Wed, Oct 20, 2021      7:30p          Boston Celtics  134
# ..                ...        ...                     ...  ...
# 88  Sun, Oct 31, 2021      3:30p        Sacramento Kings   99
# 89  Sun, Oct 31, 2021      7:00p  Portland Trail Blazers  113
# 90  Sun, Oct 31, 2021      7:00p               Utah Jazz  107
# 91  Sun, Oct 31, 2021      7:30p         Detroit Pistons   91
# 92  Sun, Oct 31, 2021     10:30p         Houston Rockets   85
#
#           Home/Neutral  PTS.1 Unnamed: 6 Unnamed: 7  Attend.  Notes
# 0      Milwaukee Bucks    127  Box Score        NaN  17341.0    NaN
# 1   Los Angeles Lakers    114  Box Score        NaN  18997.0    NaN
# ...

# %%
data={'name':['a','b','c','d'],
     'age':[23,45,67,78],
     'sex':['M','F',"M","F"]
     }

# %%
pd.DataFrame(data)
# Out:
#   name  age sex
# 0    a   23   M
# 1    b   45   F
# 2    c   67   M
# 3    d   78   F

# %%
j={"id": "0001","type": "donut","name": "Cake","ppu": 0.55,"batters":{"batter":[{ "id": "1001", "type": "Regular" },{ "id": "1002", "type": "Chocolate" },{ "id": "1003", "type": "Blueberry" },{ "id": "1004", "type": "Devil's Food" }]},"topping":[{ "id": "5001", "type": "None" },{ "id": "5002", "type": "Glazed" },{ "id": "5005", "type": "Sugar" },{ "id": "5007", "type": "Powdered Sugar" },{ "id": "5006", "type": "Chocolate with Sprinkles" },{ "id": "5003", "type": "Chocolate" },{ "id": "5004", "type": "Maple" }]}

# %%
j
# Out:
# {'id': '0001',
#  'type': 'donut',
#  'name': 'Cake',
#  'ppu': 0.55,
#  'batters': {'batter': [{'id': '1001', 'type': 'Regular'},
#    {'id': '1002', 'type': 'Chocolate'},
#    {'id': '1003', 'type': 'Blueberry'},
#    {'id': '1004', 'type': "Devil's Food"}]},
#  'topping': [{'id': '5001', 'type': 'None'},
#   {'id': '5002', 'type': 'Glazed'},
#   {'id': '5005', 'type': 'Sugar'},
#   {'id': '5007', 'type': 'Powdered Sugar'},
#   {'id': '5006', 'type': 'Chocolate with Sprinkles'},
#   {'id': '5003', 'type': 'Chocolate'},
#   {'id': '5004', 'type': 'Maple'}]}

# %%
pd.DataFrame(j['batters']['batter'])
# Out:
#      id          type
# 0  1001       Regular
# 1  1002     Chocolate
# 2  1003     Blueberry
# 3  1004  Devil's Food

# %%
pd.read_json("https://api.github.com/repos/pandas-dev/pandas/issues")
# Out:
#                                                   url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# ...

# %%
import requests

# %%
get_json=requests.get("https://api.github.com/repos/pandas-dev/pandas/issues")

# %%
type(get_json.json())
# Out:
# list

# %%
len(get_json.json())
# Out:
# 30

# %%
for i in range(len(get_json.json())):
    print(get_json.json()[i]['user']['id'])
# Out:
# 13092800
# 5902745
# 45140931
# 4567245
# 31669
# 10647082
# 10647082
# 8078968
# 10820686
# 4238978
# 8078968
# 3236794
# 97615200
# 25685004
# 3385756
# 20880292
# 8078968
# 1461273
# 36619387
# 56136443
# 20362314
# 30196
# 54762742
# 1020496
# 26364415
# 13765633
# 6618166
# 10712109
# 25179211
# 18547401

# %%
data1=get_json.json()

# %%
data1
# Out:
# [{'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46267',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46267/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46267/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46267/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/46267',
#   'id': 1162623632,
#   'node_id': 'I_kwDOAA0YD85FTDqQ',
#   'number': 46267,
#   'title': 'PERF: performance regression in assigning value to df[col_name]',
#   'user': {'login': 'Hubedge',
#    'id': 13092800,
#    'node_id': 'MDQ6VXNlcjEzMDkyODAw',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/13092800?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Hubedge',
#    'html_url': 'https://github.com/Hubedge',
# ...

# %%
df1=pd.DataFrame(data1,columns=['url','repository_url','labels_url','user'])

# %%
lst=list(df1['user'][0].keys())

# %%
lst
# Out:
# ['login',
#  'id',
#  'node_id',
#  'avatar_url',
#  'gravatar_id',
#  'url',
#  'html_url',
#  'followers_url',
#  'following_url',
#  'gists_url',
#  'starred_url',
#  'subscriptions_url',
#  'organizations_url',
#  'repos_url',
#  'events_url',
#  'received_events_url',
#  'type',
#  'site_admin']

# %%
for i in range(len(df1)):
        df1['login'][i]=df1['user'][i]['login']

print(df1['login'])
# Out:
# 0                Hubedge
# 1       johannes-mueller
# 2                   jyuv
# 3            john-bodley
# 4                 Moisan
# 5              mroeschke
# 6              mroeschke
# 7           jbrockmendel
# 8              NickCrews
# 9        Vital-Fernandez
# 10          jbrockmendel
# 11                smarie
# 12           haritha1022
# 13         franklucky001
# 14             eltenedor
# 15          ryansdowning
# 16          jbrockmendel
# 17              sterlinm
# 18               weikhor
# 19              LSturtew
# 20               ehallam
# 21                ianliu
# 22               raffaem
# 23    jorisvandenbossche
# 24            topper-123
# 25              hitvoice
# 26            twoertwein
# 27           mvashishtha
# 28            sergiykhan
# 29                moojen
# Name: login, dtype: object
