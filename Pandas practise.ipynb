# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('pokemon_data.csv')
df.head()
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
df_text=pd.read_csv('pokemon_data.txt',delimiter="\t")
df_text.head(10)
# Out:
#    #                       Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1                  Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                    Ivysaur  Grass  Poison  60      62       63       80
# 2  3                   Venusaur  Grass  Poison  80      82       83      100
# 3  3      VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4                 Charmander   Fire     NaN  39      52       43       60
# 5  5                 Charmeleon   Fire     NaN  58      64       58       80
# 6  6                  Charizard   Fire  Flying  78      84       78      109
# 7  6  CharizardMega Charizard X   Fire  Dragon  78     130      111      130
# 8  6  CharizardMega Charizard Y   Fire  Flying  78     104       78      159
# 9  7                   Squirtle  Water     NaN  44      48       65       50
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# ...

# %%
df.columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk',
#        'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
df.head(4)
df.iloc[0,3]
# Out:
# 'Poison'

# %%
df.head(4)
df.iloc[[0,4]]
# Out:
#    #        Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# 0  1   Bulbasaur  Grass  Poison  45      49       49       65       65     45
# 4  4  Charmander   Fire     NaN  39      52       43       60       50     65
#
#    Generation  Legendary
# 0           1      False
# 4           1      False

# %%
df.iloc[0]
# Out:
# #                     1
# Name          Bulbasaur
# Type 1            Grass
# Type 2           Poison
# HP                   45
# Attack               49
# Defense              49
# Sp. Atk              65
# Sp. Def              65
# Speed                45
# Generation            1
# Legendary         False
# Name: 0, dtype: object

# %%
df.iloc[0:4]
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False

# %%
df.loc[df['Type 1']=='Poison']
# Out:
#        #              Name  Type 1    Type 2   HP  Attack  Defense  Sp. Atk  \
# 28    23             Ekans  Poison       NaN   35      60       44       40
# 29    24             Arbok  Poison       NaN   60      85       69       65
# 34    29  Nidoran (Female)  Poison       NaN   55      47       52       40
# 35    30          Nidorina  Poison       NaN   70      62       67       55
# 36    31         Nidoqueen  Poison    Ground   90      92       87       75
# 37    32    Nidoran (Male)  Poison       NaN   46      57       40       40
# 38    33          Nidorino  Poison       NaN   61      72       57       55
# 39    34          Nidoking  Poison    Ground   81     102       77       85
# 46    41             Zubat  Poison    Flying   40      45       35       30
# 47    42            Golbat  Poison    Flying   75      80       70       65
# 95    88            Grimer  Poison       NaN   80      80       50       40
# ...

# %%
df.head()
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
df.describe()
# Out:
#                 #          HP      Attack     Defense     Sp. Atk     Sp. Def  \
# count  800.000000  800.000000  800.000000  800.000000  800.000000  800.000000
# mean   362.813750   69.258750   79.001250   73.842500   72.820000   71.902500
# std    208.343798   25.534669   32.457366   31.183501   32.722294   27.828916
# min      1.000000    1.000000    5.000000    5.000000   10.000000   20.000000
# 25%    184.750000   50.000000   55.000000   50.000000   49.750000   50.000000
# 50%    364.500000   65.000000   75.000000   70.000000   65.000000   70.000000
# 75%    539.250000   80.000000  100.000000   90.000000   95.000000   90.000000
# max    721.000000  255.000000  190.000000  230.000000  194.000000  230.000000
#
#             Speed  Generation
# count  800.000000   800.00000
# mean    68.277500     3.32375
# std     29.060474     1.66129
# min      5.000000     1.00000
# 25%     45.000000     2.00000
# 50%     65.000000     3.00000
# 75%     90.000000     5.00000
# ...

# %%
df['Type 1'].describe()
# Out:
# count       800
# unique       18
# top       Water
# freq        112
# Name: Type 1, dtype: object

# %%
df.sort_values('HP',ascending=1)
# Out:
#        #       Name   Type 1 Type 2   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 316  292   Shedinja      Bug  Ghost    1      90       45       30       30
# 55    50    Diglett   Ground    NaN   10      55       25       35       45
# 139  129   Magikarp    Water    NaN   20      10       55       15       20
# 388  355    Duskull    Ghost    NaN   20      40       90       30       90
# 487  439   Mime Jr.  Psychic  Fairy   20      25       45       70       90
# ..   ...        ...      ...    ...  ...     ...      ...      ...      ...
# 655  594  Alomomola    Water    NaN  165      75       80       40       45
# 351  321    Wailord    Water    NaN  170      90       45       90       45
# 217  202  Wobbuffet  Psychic    NaN  190      33       58       33       58
# 121  113    Chansey   Normal    NaN  250       5        5       35      105
# 261  242    Blissey   Normal    NaN  255      10       10       75      135
#
#      Speed  Generation  Legendary
# ...

# %%
df['Total']=False
df=df.drop(columns='Total')
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
df.to_csv('modified.csv')

# %%
df.loc[:,['Type 2']]
# Out:
#      Type 2
# 0    Poison
# 1    Poison
# 2    Poison
# 3    Poison
# 4       NaN
# ..      ...
# 795   Fairy
# 796   Fairy
# 797   Ghost
# 798    Dark
# 799   Water
#
# [800 rows x 1 columns]

# %%
df.head()
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
new_df=df.loc[(df['HP']==80) & (df['Speed']>60)]
new_df
# Out:
#        #                       Name    Type 1    Type 2  HP  Attack  Defense  \
# 2      3                   Venusaur     Grass    Poison  80      82       83
# 3      3      VenusaurMega Venusaur     Grass    Poison  80     100      123
# 60    55                    Golduck     Water       NaN  80      82       78
# 77    71                 Victreebel     Grass    Poison  80     105       65
# 79    73                 Tentacruel     Water    Poison  80      70       65
# 128  119                    Seaking     Water       NaN  80      92       65
# 153  142                 Aerodactyl      Rock    Flying  80     105       65
# 154  142  AerodactylMega Aerodactyl      Rock    Flying  80     135       85
# 168  154                   Meganium     Grass       NaN  80      82      100
# 231  214                  Heracross       Bug  Fighting  80     125       75
# 232  214    HeracrossMega Heracross       Bug  Fighting  80     185      115
# ...

# %%
new_df.reset_index(drop=True,inplace=True)
new_df
# Out:
#       #                       Name    Type 1    Type 2  HP  Attack  Defense  \
# 0     3                   Venusaur     Grass    Poison  80      82       83
# 1     3      VenusaurMega Venusaur     Grass    Poison  80     100      123
# 2    55                    Golduck     Water       NaN  80      82       78
# 3    71                 Victreebel     Grass    Poison  80     105       65
# 4    73                 Tentacruel     Water    Poison  80      70       65
# 5   119                    Seaking     Water       NaN  80      92       65
# 6   142                 Aerodactyl      Rock    Flying  80     105       65
# 7   142  AerodactylMega Aerodactyl      Rock    Flying  80     135       85
# 8   154                   Meganium     Grass       NaN  80      82      100
# 9   214                  Heracross       Bug  Fighting  80     125       75
# 10  214    HeracrossMega Heracross       Bug  Fighting  80     185      115
# ...

# %%
df.
# Out:
# (800, 12)

# %%
import numpy as np

# %%
s=np.random.randn(4,4)
s
# Out:
# array([[-0.86009861, -0.9224562 ,  2.07385514, -1.80046524],
#        [ 1.78977735, -0.48705584,  0.4121662 , -0.20760083],
#        [-0.37855019,  0.76151323,  1.21458778,  0.08703061],
#        [-0.39056476, -1.15280519, -2.89671439,  1.31093015]])

# %%
df1=pd.DataFrame(s,[1,2,3,4],'A B C D'.split())
df1
# Out:
#           A         B         C         D
# 1 -0.860099 -0.922456  2.073855 -1.800465
# 2  1.789777 -0.487056  0.412166 -0.207601
# 3 -0.378550  0.761513  1.214588  0.087031
# 4 -0.390565 -1.152805 -2.896714  1.310930

# %%
type(df1[['A','B','C']])
# Out:
# pandas.core.frame.DataFrame

# %%
df1['new']=np.random.randn()
df1
# Out:
#           A         B         C         D       new
# 1 -0.860099 -0.922456  2.073855 -1.800465  0.003366
# 2  1.789777 -0.487056  0.412166 -0.207601  0.003366
# 3 -0.378550  0.761513  1.214588  0.087031  0.003366
# 4 -0.390565 -1.152805 -2.896714  1.310930  0.003366

# %%
df1.drop('new',axis=1,inplace=True)

# %%
df1
# Out:
#           A         B         C         D
# 1 -0.860099 -0.922456  2.073855 -1.800465
# 2  1.789777 -0.487056  0.412166 -0.207601
# 3 -0.378550  0.761513  1.214588  0.087031
# 4 -0.390565 -1.152805 -2.896714  1.310930

# %%
df1
# Out:
#           A         B         C         D
# 1 -0.860099 -0.922456  2.073855 -1.800465
# 2  1.789777 -0.487056  0.412166 -0.207601
# 3 -0.378550  0.761513  1.214588  0.087031

# %%
df1[['A','B']]
# Out:
#           A         B
# 1 -0.860099 -0.922456
# 2  1.789777 -0.487056
# 3 -0.378550  0.761513

# %%
type(df1.loc[1])
# Out:
# pandas.core.series.Series

# %%
df1.iloc[0,1]
# Out:
# -0.9224562041758986

# %%
df1.loc[:,['B','A']]
# Out:
#           B         A
# 1 -0.922456 -0.860099
# 2 -0.487056  1.789777
# 3  0.761513 -0.378550

# %%
df1.iloc[[0,1],[1,0]]
# Out:
#           B         A
# 1 -0.922456 -0.860099
# 2 -0.487056  1.789777

# %%
df1
# Out:
#           A         B         C         D
# 1 -0.860099 -0.922456  2.073855 -1.800465
# 2  1.789777 -0.487056  0.412166 -0.207601
# 3 -0.378550  0.761513  1.214588  0.087031

# %%
df1[df1['A']>0][['B','C']]
# Out:
#           B         C
# 2 -0.487056  0.412166

# %%
df1['E']=['w','x','y']
df1.set_index('E',inplace=True)
df1.reset_index(inplace=True)
df1
# Out:
#    E         A         B         C         D
# 0  w -0.860099 -0.922456  2.073855 -1.800465
# 1  x  1.789777 -0.487056  0.412166 -0.207601
# 2  y -0.378550  0.761513  1.214588  0.087031

# %%
df1=df1['A B C D E'.split()]
df1
# Out:
#           A         B         C         D  E
# 0 -0.860099 -0.922456  2.073855 -1.800465  w
# 1  1.789777 -0.487056  0.412166 -0.207601  x
# 2 -0.378550  0.761513  1.214588  0.087031  y

# %%
df.
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk',
#        'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
a=[[1,2,3],[1,4,5],[2,6,8]]
pd.DataFrame(a,columns=['a','b','c'])
# Out:
#    a  b  c
# 0  1  2  3
# 1  1  4  5
# 2  2  6  8

# %%
y=pd.DataFrame({'A':[1,2,np.nan,4],'B':[6,7,8,np.nan],'C':[8,9,np.nan,11],'D':[44,np.nan,np.nan,np.nan]})
y
# Out:
#      A    B     C     D
# 0  1.0  6.0   8.0  44.0
# 1  2.0  7.0   9.0   NaN
# 2  NaN  8.0   NaN   NaN
# 3  4.0  NaN  11.0   NaN

# %%
y.dropna()
# Out:
# 0                                                  1.0
# 1                                                  2.0
# 2    <bound method NDFrame._add_numeric_operations....
# 3                                                  4.0
# Name: A, dtype: object

# %%
y['A'].fillna(value=y['B'].median(),inplace=True)
y
# Out:
#      A    B     C     D
# 0  1.0  6.0   8.0  44.0
# 1  2.0  7.0   9.0   NaN
# 2  7.0  8.0   NaN   NaN
# 3  4.0  NaN  11.0   NaN

# %%
data = {'Company':['GOOG','GOOG','MSFT','MSFT','FB','FB'],
       'Person':['Sam','Charlie','Amy','Vanessa','Carl','Sarah'],
       'Sales':[200,120,340,124,243,350]}

# %%
df2=pd.DataFrame(data)
df2
# Out:
#   Company   Person  Sales
# 0    GOOG      Sam    200
# 1    GOOG  Charlie    120
# 2    MSFT      Amy    340
# 3    MSFT  Vanessa    124
# 4      FB     Carl    243
# 5      FB    Sarah    350

# %%
grouped=df2.groupby('Company',sort=True)
grouped['Person','Sales'].min()
# Out:
# /var/folders/h9/p7sjv2cd7hg3qp4_5wg8hz4r0000gn/T/ipykernel_27659/1360492660.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   grouped['Person','Sales'].min()
#           Person  Sales
# Company
# FB          Carl    243
# GOOG     Charlie    120
# MSFT         Amy    124

# %%
df1 = pd.DataFrame({'A': ['A0', 'A1', 'A2', 'A3'],
                        'B': ['B0', 'B1', 'B2', 'B3'],
                        'C': ['C0', 'C1', 'C2', 'C3'],
                        'D': ['D0', 'D1', 'D2', 'D3']},
                        index=[1,2,3,4])

# %%
df1
# Out:
#     A   B   C   D
# 1  A0  B0  C0  D0
# 2  A1  B1  C1  D1
# 3  A2  B2  C2  D2
# 4  A3  B3  C3  D3

# %%
df2 = pd.DataFrame({'A': ['A4', 'A5', 'A6', 'A7'],
                        'B': ['B4', 'B5', 'B6', 'B7'],
                        'C': ['C4', 'C5', 'C6', 'C7']},
                        index=[4, 5, 6,7]) 
df2
# Out:
#     A   B   C
# 4  A4  B4  C4
# 5  A5  B5  C5
# 6  A6  B6  C6
# 7  A7  B7  C7

# %%
pd.concat([df1,df2],axis=1)
# Out:
#      A    B    C    D    A    B    C
# 1   A0   B0   C0   D0  NaN  NaN  NaN
# 2   A1   B1   C1   D1  NaN  NaN  NaN
# 3   A2   B2   C2   D2  NaN  NaN  NaN
# 4   A3   B3   C3   D3   A4   B4   C4
# 5  NaN  NaN  NaN  NaN   A5   B5   C5
# 6  NaN  NaN  NaN  NaN   A6   B6   C6
# 7  NaN  NaN  NaN  NaN   A7   B7   C7
